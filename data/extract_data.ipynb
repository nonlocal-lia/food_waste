# %% [markdown]
# # Extracting Data from PDFs

# %%
import tabula
import pandas as pd

# %%
data_2018 = "./2018_tables_and_figures_dec_2020_fnl_508.pdf"

# %%
template = "./tabula-2018_tables_and_figures_dec_2020_fnl_508.json"

# %%
table = tabula.read_pdf_with_template(input_path=data_2018, template_path=template)
table[0]
# Out:
#                         Unnamed: 0    1960     1970     1980     1990  \
# 0             Paper and Paperboard  29,990   44,310   55,160   72,730
# 1                            Glass   6,720   12,740   15,130   13,100
# 2                           Metals     NaN      NaN      NaN      NaN
# 3                          Ferrous  10,300   12,360   12,620   12,640
# 4                         Aluminum     340      800    1,730    2,810
# 5                 Other Nonferrous     180      670    1,160    1,100
# 6                     Total Metals  10,820   13,830   15,510   16,550
# 7                         Plastics     390    2,900    6,830   17,130
# 8               Rubber and Leather   1,840    2,970    4,200    5,790
# 9                         Textiles   1,760    2,040    2,530    5,810
# 10                            Wood   3,030    3,720    7,010   12,210
# 11                        Other **      70      770    2,520    3,190
# ...

# %%
table[1]
# Out:
#                         Unnamed: 0    1960    1970    1980    1990    2000  \
# 0             Paper and Paperboard   34.0%   36.6%   36.4%   34.9%   36.0%
# 1                            Glass    7.6%   10.5%   10.0%    6.3%    5.2%
# 2                           Metals     NaN     NaN     NaN     NaN     NaN
# 3                          Ferrous   11.7%   10.2%    8.3%    6.1%    5.8%
# 4                         Aluminum    0.4%    0.7%    1.1%    1.3%    1.3%
# 5                 Other Nonferrous    0.2%    0.6%    0.8%    0.5%    0.7%
# 6                     Total Metals   12.3%   11.4%   10.2%    7.9%    7.8%
# 7                         Plastics    0.4%    2.4%    4.5%    8.2%   10.5%
# 8               Rubber and Leather    2.1%    2.5%    2.8%    2.8%    2.7%
# 9                         Textiles    2.0%    1.7%    1.7%    2.8%    3.9%
# 10                            Wood    3.4%    3.1%    4.6%    5.9%    5.6%
# ...

# %%
table[2]
# Out:
#    Paper and Paperboard  5,080  6,770  11,740  20,230  37,560  41,960  44,570  \
# 0                 Glass    100    160     750   2,630   2,880   2,590   3,130
# 1                Metals    NaN    NaN     NaN     NaN     NaN     NaN     NaN
# 2               Ferrous     50    150     370   2,230   4,680   5,020   5,800
# 3              Aluminum   Neg.     10     310   1,010     860     690     680
# 4      Other Nonferrous   Neg.    320     540     730   1,060   1,280   1,440
# 5          Total Metals     50    480   1,220   3,970   6,600   6,990   7,920
# 6              Plastics   Neg.   Neg.      20     370   1,480   1,780   2,500
# 7    Rubber and Leather    330    250     130     370     820   1,050   1,440
# 8              Textiles     50     60     160     660   1,320   1,830   2,050
# 9                  Wood   Neg.   Neg.    Neg.     130   1,370   1,830   2,280
# 10             Other **   Neg.    300     500     680     980   1,210   1,370
# ...

# %%
table[3]
# Out:
#                      Food - composted Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0                               Food^       Neg.       Neg.       Neg.
# 1          Yard Trimmings - composted        NaN        NaN        NaN
# 2                      Yard Trimmings       Neg.       Neg.       Neg.
# 3  Misc. Inorganic Wastes - composted        NaN        NaN        NaN
# 4      Miscellaneous Inorganic Wastes       Neg.       Neg.       Neg.
# 5                   Total - composted       Neg.       Neg.       Neg.
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0       Neg.        680        690        970      2,100      2,570      2,590
# 1        NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 2      4,200     15,770     19,860     19,200     21,290     24,420     22,300
# 3        NaN        NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
table[4]
# Out:
#                    Food - animal feed
# 0                    Food - bio-based
# 1    materials/biochemical processing
# 2        Food – codigestion/anaerobic
# 3                           digestion
# 4                     Food - donation
# 5             Food - land application
# 6             Food – sewer/wastewater
# 7                           treatment
# 8  Total Food – other food management

# %%
table[5]
# Out:
#     1,820
# 0   1,840
# 1   5,260
# 2   4,790
# 3     260
# 4   3,740
# 5  17,710

# %%
table[6]
# Out:
#                                 Unnamed: 0   1960   1970   1980   1990   2000  \
# 0                                 Recycled    NaN    NaN    NaN    NaN    NaN
# 1                     Paper and Paperboard  16.9%  15.3%  21.3%  27.8%  42.8%
# 2                                    Glass   1.5%   1.3%   5.0%  20.1%  22.6%
# 3                                   Metals    NaN    NaN    NaN    NaN    NaN
# 4                                  Ferrous   0.5%   1.2%   2.9%  17.6%  33.1%
# 5                                 Aluminum   Neg.   1.3%  17.9%  35.9%  27.0%
# 6                         Other Nonferrous   Neg.  47.8%  46.6%  66.4%  66.3%
# 7                             Total Metals   0.5%   3.5%   7.9%  24.0%  34.8%
# 8                                 Plastics   Neg.   Neg.   0.3%   2.2%   5.8%
# 9                       Rubber and Leather  17.9%   8.4%   3.1%   6.4%  12.3%
# 10                                Textiles   2.8%   2.9%   6.3%  11.4%  13.9%
# ...

# %%
table[7]
# Out:
#                      Food - Composted Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0                               Food^       Neg.       Neg.       Neg.
# 1          Yard Trimmings - Composted        NaN        NaN        NaN
# 2                      Yard Trimmings       Neg.       Neg.       Neg.
# 3  Misc. Inorganic Wastes – composted        NaN        NaN        NaN
# 4      Miscellaneous Inorganic Wastes       Neg.       Neg.       Neg.
# 5                   Total – composted       Neg.       Neg.       Neg.
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0       Neg.       2.2%       2.1%       2.7%       5.3%       6.3%       4.1%
# 1        NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 2      12.0%      51.7%      61.9%      57.5%      61.3%      69.4%      63.0%
# 3        NaN        NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
table[8]
# Out:
#                Other Food Management¥
# 0                  Food - animal feed
# 1                    Food - bio-based
# 2    materials/biochemical processing
# 3        Food – codigestion/anaerobic
# 4                           digestion
# 5                     Food - donation
# 6             Food - land application
# 7             Food – sewer/wastewater
# 8                           treatment
# 9  Total Food – other food management

# %%
table[9]
# Out:
#     2.9%
# 0   2.9%
# 1   8.3%
# 2   7.6%
# 3   0.4%
# 4   5.9%
# 5  28.1%

# %%
table[10]
# Out:
#                         Unnamed: 0  1960   1970   1980    1990    2000  \
# 0             Paper and Paperboard   NaN  150.0    860   8,930   9,730
# 1                            Glass   NaN   60.0    300   1,810   1,790
# 2                           Metals   NaN    NaN    NaN     NaN     NaN
# 3                          Ferrous   NaN   60.0    250   1,690   1,610
# 4                         Aluminum   NaN    0.0     30     300     390
# 5                 Other Nonferrous   NaN    0.0     20      60      50
# 6                     Total Metals   NaN   60.0    300   2,050   2,050
# 7                         Plastics   NaN    0.0    140   2,980   4,120
# 8               Rubber and Leather   NaN   10.0     70     830   1,970
# 9                         Textiles   NaN   10.0     50     880   1,880
# 10                            Wood   NaN   10.0    150   2,080   2,290
# 11                        Other **   NaN    0.0     30     410     540
# ...

# %%
table[11]
# Out:
#                                      Unnamed: 0  1960    1970    1980    1990  \
# 0                          Paper and Paperboard   NaN   33.3%   31.2%   30.0%
# 1                                         Glass   NaN   13.3%   10.9%    6.1%
# 2                                        Metals   NaN     NaN     NaN     NaN
# 3                                       Ferrous   NaN   13.3%    9.0%    5.7%
# 4                                      Aluminum   NaN    0.0%    1.1%    1.0%
# 5                              Other Nonferrous   NaN    0.0%    0.7%    0.2%
# 6                                  Total Metals   NaN   13.3%   10.8%    6.9%
# 7                                      Plastics   NaN    Neg.    5.1%   10.0%
# 8                            Rubber and Leather   NaN    2.2%    2.5%    2.8%
# 9                                      Textiles   NaN    2.2%    1.8%    2.9%
# 10                                         Wood   NaN    2.2%    5.4%    7.0%
# ...

# %%
table[12]
# Out:
#                      Unnamed: 0    1960    1970    1980    1990     2000  \
# 0          Paper and Paperboard  24,910  37,390  42,560  43,570   40,450
# 1                         Glass   6,620  12,520  14,080   8,660    8,100
# 2                        Metals     NaN     NaN     NaN     NaN      NaN
# 3                       Ferrous  10,250  12,150  12,000   8,720    7,860
# 4                      Aluminum     340     790   1,390   1,500    1,940
# 5              Other Nonferrous     180     350     600     310      490
# 6                  Total Metals  10,770  13,290  13,990  10,530   10,290
# 7                      Plastics     390   2,900   6,670  13,780   19,950
# 8            Rubber and Leather   1,510   2,710   4,000   4,590    3,880
# 9                      Textiles   1,710   1,970   2,320   4,270    6,280
# 10                         Wood   3,030   3,710   6,860  10,000    9,910
# 11                     Other **      70     470   1,990   2,100    2,480
# ...

# %%
table[13]
# Out:
#                      Unnamed: 0   1960   1970   1980   1990   2000   2005  \
# 0          Paper and Paperboard  30.2%  33.2%  31.7%  30.0%  28.8%  24.7%
# 1                         Glass   8.0%  11.1%  10.5%   6.0%   5.8%   5.8%
# 2                        Metals    NaN    NaN    NaN    NaN    NaN    NaN
# 3                       Ferrous  12.4%  10.8%   8.9%   6.0%   5.6%   6.0%
# 4                      Aluminum   0.4%   0.7%   1.0%   1.0%   1.4%   1.6%
# 5              Other Nonferrous   0.2%   0.3%   0.4%   0.2%   0.3%   0.3%
# 6                  Total Metals  13.0%  11.8%  10.3%   7.2%   7.3%   7.9%
# 7                      Plastics   0.5%   2.6%   5.0%   9.5%  14.2%  16.4%
# 8            Rubber and Leather   1.8%   2.4%   3.0%   3.2%   2.8%   2.9%
# 9                      Textiles   2.1%   1.7%   1.7%   2.9%   4.5%   5.3%
# 10                         Wood   3.7%   3.3%   5.1%   6.9%   7.1%   7.5%
# 11                     Other **   0.1%   0.4%   1.5%   1.4%   1.8%   1.8%
# ...

# %%
generated_absolute = table[0]
generated_percent_total = table[1]
recycled = table[2]
composted = table[3]
other_label = table[4]
other_values = table[5]
recycled_percent = table[6]
composted_percent = table[7]
other_label_percent = table[8]
other_values_percent = table[9]
combusted = table[10]
combusted_percent = table[11]
landfilled = table[12]
landfilled_percent = table[13]

# %% [markdown]
# ### Fixing Divided Tables

# %% [markdown]
# Two of the tables didn't load well and the labels and values were stored in seperate tables, we will clean them up so their rows align and then concat them together

# %%
other_label
# Out:
#                    Food - animal feed
# 0                    Food - bio-based
# 1    materials/biochemical processing
# 2        Food – codigestion/anaerobic
# 3                           digestion
# 4                     Food - donation
# 5             Food - land application
# 6             Food – sewer/wastewater
# 7                           treatment
# 8  Total Food – other food management

# %%
# Fixing labels that interpreter treated as seperate lines
other_label.iloc[0,0] = other_label.iloc[0,0] + ' ' + other_label.iloc[1,0]
other_label.iloc[2,0] = other_label.iloc[2,0] + ' ' + other_label.iloc[3,0]
other_label.iloc[6,0] = other_label.iloc[6,0] + ' ' + other_label.iloc[7,0]

# droping extra lines
other_label.drop([1,3,7] ,inplace=True)

# resetting index
other_label.reset_index(inplace=True)
other_label.drop(columns=['index'], inplace=True)
other_label
# Out:
#                                   Food - animal feed
# 0  Food - bio-based materials/biochemical processing
# 1             Food – codigestion/anaerobic digestion
# 2                                    Food - donation
# 3                            Food - land application
# 4                  Food – sewer/wastewater treatment
# 5                 Total Food – other food management

# %%
# column title is actually another row label, creating row from column title
other_label = other_label.columns.to_frame().T.append(other_label, ignore_index=True)
other_label
# Out:
#                                   Food - animal feed
# 0                                 Food - animal feed
# 1  Food - bio-based materials/biochemical processing
# 2             Food – codigestion/anaerobic digestion
# 3                                    Food - donation
# 4                            Food - land application
# 5                  Food – sewer/wastewater treatment
# 6                 Total Food – other food management

# %%
# column title is actually a value, creating row from column title
other_values = other_values.columns.to_frame().T.append(other_values, ignore_index=True)
other_values
# Out:
#     1,820
# 0   1,820
# 1   1,840
# 2   5,260
# 3   4,790
# 4     260
# 5   3,740
# 6  17,710

# %%
# Joining and relabeling columns
other = pd.concat([other_label, other_values], axis=1)
other.columns = ['Material', 'Amount']
other
# Out:
#                                             Material  Amount
# 0                                 Food - animal feed   1,820
# 1  Food - bio-based materials/biochemical processing   1,840
# 2             Food – codigestion/anaerobic digestion   5,260
# 3                                    Food - donation   4,790
# 4                            Food - land application     260
# 5                  Food – sewer/wastewater treatment   3,740
# 6                 Total Food – other food management  17,710

# %%
# column title is actually a value, creating row from column title
other_values_percent = other_values_percent.columns.to_frame().T.append(other_values_percent, ignore_index=True)
other_values_percent
# Out:
#     2.9%
# 0   2.9%
# 1   2.9%
# 2   8.3%
# 3   7.6%
# 4   0.4%
# 5   5.9%
# 6  28.1%

# %%
# Since labels in both tables are identical, joining percent values with already fixed labels
other_percent = pd.concat([other_label, other_values_percent], axis=1)
other_percent.columns = ['Material', 'Percent']
other_percent
# Out:
#                                             Material Percent
# 0                                 Food - animal feed    2.9%
# 1  Food - bio-based materials/biochemical processing    2.9%
# 2             Food – codigestion/anaerobic digestion    8.3%
# 3                                    Food - donation    7.6%
# 4                            Food - land application    0.4%
# 5                  Food – sewer/wastewater treatment    5.9%
# 6                 Total Food – other food management   28.1%

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# Some rows were actually just more table labels, we will clean them up to make the data more workable.

# %%
generated_absolute
# Out:
#                         Unnamed: 0    1960     1970     1980     1990  \
# 0             Paper and Paperboard  29,990   44,310   55,160   72,730
# 1                            Glass   6,720   12,740   15,130   13,100
# 2                           Metals     NaN      NaN      NaN      NaN
# 3                          Ferrous  10,300   12,360   12,620   12,640
# 4                         Aluminum     340      800    1,730    2,810
# 5                 Other Nonferrous     180      670    1,160    1,100
# 6                     Total Metals  10,820   13,830   15,510   16,550
# 7                         Plastics     390    2,900    6,830   17,130
# 8               Rubber and Leather   1,840    2,970    4,200    5,790
# 9                         Textiles   1,760    2,040    2,530    5,810
# 10                            Wood   3,030    3,720    7,010   12,210
# 11                        Other **      70      770    2,520    3,190
# ...

# %%
# removing metal and other wastes rows that were just labels in table and relabing data for clarity
generated_absolute.iloc[3,0] = generated_absolute.iloc[2,0] +" - "+generated_absolute.iloc[3,0]
generated_absolute.iloc[4,0] = generated_absolute.iloc[2,0] +" - "+generated_absolute.iloc[4,0]
generated_absolute.iloc[5,0] = generated_absolute.iloc[2,0] +" - "+generated_absolute.iloc[5,0]
generated_absolute.iloc[6,0] = generated_absolute.iloc[2,0] +" - "+generated_absolute.iloc[6,0]
generated_absolute.drop([2,13], inplace=True)

# %%
# renaming columns and setting index to row labels
generated_absolute.rename(columns={generated_absolute.columns[0]: 'Material'}, inplace=True)
generated_absolute.set_index('Material', inplace=True)
generated_absolute
# Out:
#                                   1960     1970     1980     1990     2000  \
# Material
# Paper and Paperboard            29,990   44,310   55,160   72,730   87,740
# Glass                            6,720   12,740   15,130   13,100   12,770
# Metals - Ferrous                10,300   12,360   12,620   12,640   14,150
# Metals - Aluminum                  340      800    1,730    2,810    3,190
# Metals - Other Nonferrous          180      670    1,160    1,100    1,600
# Metals - Total Metals           10,820   13,830   15,510   16,550   18,940
# Plastics                           390    2,900    6,830   17,130   25,550
# Rubber and Leather               1,840    2,970    4,200    5,790    6,670
# Textiles                         1,760    2,040    2,530    5,810    9,480
# Wood                             3,030    3,720    7,010   12,210   13,570
# Other **                            70      770    2,520    3,190    4,000
# ...

# %%
# Save cleaned data
generated_absolute.to_csv("absolute_generated_waste_table.csv")

# %%
generated_percent_total
# Out:
#                         Unnamed: 0    1960    1970    1980    1990    2000  \
# 0             Paper and Paperboard   34.0%   36.6%   36.4%   34.9%   36.0%
# 1                            Glass    7.6%   10.5%   10.0%    6.3%    5.2%
# 2                           Metals     NaN     NaN     NaN     NaN     NaN
# 3                          Ferrous   11.7%   10.2%    8.3%    6.1%    5.8%
# 4                         Aluminum    0.4%    0.7%    1.1%    1.3%    1.3%
# 5                 Other Nonferrous    0.2%    0.6%    0.8%    0.5%    0.7%
# 6                     Total Metals   12.3%   11.4%   10.2%    7.9%    7.8%
# 7                         Plastics    0.4%    2.4%    4.5%    8.2%   10.5%
# 8               Rubber and Leather    2.1%    2.5%    2.8%    2.8%    2.7%
# 9                         Textiles    2.0%    1.7%    1.7%    2.8%    3.9%
# 10                            Wood    3.4%    3.1%    4.6%    5.9%    5.6%
# ...

# %%
# removing metal and other wastes rows that were just labels in table and relabing data for clarity
generated_percent_total.iloc[3,0] = generated_percent_total.iloc[2,0] +" - "+generated_percent_total.iloc[3,0]
generated_percent_total.iloc[4,0] = generated_percent_total.iloc[2,0] +" - "+generated_percent_total.iloc[4,0]
generated_percent_total.iloc[5,0] = generated_percent_total.iloc[2,0] +" - "+generated_percent_total.iloc[5,0]
generated_percent_total.iloc[6,0] = generated_percent_total.iloc[2,0] +" - "+generated_percent_total.iloc[6,0]
generated_percent_total.drop([2,13], inplace=True)

# renaming columns and setting index to row labels
generated_percent_total.rename(columns={generated_percent_total.columns[0]: 'Material'}, inplace=True)
generated_percent_total.set_index('Material', inplace=True)
generated_percent_total
# Out:
#                                   1960    1970    1980    1990    2000  \
# Material
# Paper and Paperboard             34.0%   36.6%   36.4%   34.9%   36.0%
# Glass                             7.6%   10.5%   10.0%    6.3%    5.2%
# Metals - Ferrous                 11.7%   10.2%    8.3%    6.1%    5.8%
# Metals - Aluminum                 0.4%    0.7%    1.1%    1.3%    1.3%
# Metals - Other Nonferrous         0.2%    0.6%    0.8%    0.5%    0.7%
# Metals - Total Metals            12.3%   11.4%   10.2%    7.9%    7.8%
# Plastics                          0.4%    2.4%    4.5%    8.2%   10.5%
# Rubber and Leather                2.1%    2.5%    2.8%    2.8%    2.7%
# Textiles                          2.0%    1.7%    1.7%    2.8%    3.9%
# Wood                              3.4%    3.1%    4.6%    5.9%    5.6%
# Other **                          0.1%    0.6%    1.7%    1.5%    1.6%
# Total Materials in Products      62.0%   68.8%   71.8%   70.3%   73.4%
# ...

# %%
generated_percent_total.to_csv("percent_generated_waste_table.csv")

# %%
recycled
# Out:
#    Paper and Paperboard  5,080  6,770  11,740  20,230  37,560  41,960  44,570  \
# 0                 Glass    100    160     750   2,630   2,880   2,590   3,130
# 1                Metals    NaN    NaN     NaN     NaN     NaN     NaN     NaN
# 2               Ferrous     50    150     370   2,230   4,680   5,020   5,800
# 3              Aluminum   Neg.     10     310   1,010     860     690     680
# 4      Other Nonferrous   Neg.    320     540     730   1,060   1,280   1,440
# 5          Total Metals     50    480   1,220   3,970   6,600   6,990   7,920
# 6              Plastics   Neg.   Neg.      20     370   1,480   1,780   2,500
# 7    Rubber and Leather    330    250     130     370     820   1,050   1,440
# 8              Textiles     50     60     160     660   1,320   1,830   2,050
# 9                  Wood   Neg.   Neg.    Neg.     130   1,370   1,830   2,280
# 10             Other **   Neg.    300     500     680     980   1,210   1,370
# ...

# %%
# removing metal and other wastes rows that were just labels in table and relabing data for clarity
recycled.iloc[2,0] = recycled.iloc[1,0] +" - "+recycled.iloc[2,0]
recycled.iloc[3,0] = recycled.iloc[1,0] +" - "+recycled.iloc[3,0]
recycled.iloc[4,0] = recycled.iloc[1,0] +" - "+recycled.iloc[4,0]
recycled.drop([1], inplace=True)

# column labels are actual data, copying data into table
recycled = recycled.columns.to_frame().T.append(recycled, ignore_index=True)

# renaming columns and setting index to row labels
column_names = generated_percent_total.reset_index().columns
recycled.columns = column_names
recycled.set_index('Material', inplace=True)
recycled
# Out:
#                             1960   1970    1980    1990    2000    2005  \
# Material
# Paper and Paperboard       5,080  6,770  11,740  20,230  37,560  41,960
# Glass                        100    160     750   2,630   2,880   2,590
# Metals - Ferrous              50    150     370   2,230   4,680   5,020
# Metals - Aluminum           Neg.     10     310   1,010     860     690
# Metals - Other Nonferrous   Neg.    320     540     730   1,060   1,280
# Total Metals                  50    480   1,220   3,970   6,600   6,990
# Plastics                    Neg.   Neg.      20     370   1,480   1,780
# Rubber and Leather           330    250     130     370     820   1,050
# Textiles                      50     60     160     660   1,320   1,830
# Wood                        Neg.   Neg.    Neg.     130   1,370   1,830
# Other **                    Neg.    300     500     680     980   1,210
# Total MSW recycled         5,610  8,020  14,520  29,040  53,010  59,240
#
# ...

# %%
recycled.to_csv("absolute_recycled_table.csv")

# %%
recycled_percent
# Out:
#                                 Unnamed: 0   1960   1970   1980   1990   2000  \
# 0                                 Recycled    NaN    NaN    NaN    NaN    NaN
# 1                     Paper and Paperboard  16.9%  15.3%  21.3%  27.8%  42.8%
# 2                                    Glass   1.5%   1.3%   5.0%  20.1%  22.6%
# 3                                   Metals    NaN    NaN    NaN    NaN    NaN
# 4                                  Ferrous   0.5%   1.2%   2.9%  17.6%  33.1%
# 5                                 Aluminum   Neg.   1.3%  17.9%  35.9%  27.0%
# 6                         Other Nonferrous   Neg.  47.8%  46.6%  66.4%  66.3%
# 7                             Total Metals   0.5%   3.5%   7.9%  24.0%  34.8%
# 8                                 Plastics   Neg.   Neg.   0.3%   2.2%   5.8%
# 9                       Rubber and Leather  17.9%   8.4%   3.1%   6.4%  12.3%
# 10                                Textiles   2.8%   2.9%   6.3%  11.4%  13.9%
# ...

# %%
# removing metal and other wastes rows that were just labels in table and relabing data for clarity
recycled_percent.iloc[4,0] = recycled_percent.iloc[3,0] +" - "+recycled_percent.iloc[4,0]
recycled_percent.iloc[5,0] = recycled_percent.iloc[3,0] +" - "+recycled_percent.iloc[5,0]
recycled_percent.iloc[6,0] = recycled_percent.iloc[3,0] +" - "+recycled_percent.iloc[6,0]
recycled_percent.drop([0,3], inplace=True)

# renaming columns and setting index to row labels
recycled_percent.columns = column_names
recycled_percent.set_index('Material', inplace=True)
recycled_percent
# Out:
#                                          1960   1970   1980   1990   2000  \
# Material
# Paper and Paperboard                    16.9%  15.3%  21.3%  27.8%  42.8%
# Glass                                    1.5%   1.3%   5.0%  20.1%  22.6%
# Metals - Ferrous                         0.5%   1.2%   2.9%  17.6%  33.1%
# Metals - Aluminum                        Neg.   1.3%  17.9%  35.9%  27.0%
# Metals - Other Nonferrous                Neg.  47.8%  46.6%  66.4%  66.3%
# Total Metals                             0.5%   3.5%   7.9%  24.0%  34.8%
# Plastics                                 Neg.   Neg.   0.3%   2.2%   5.8%
# Rubber and Leather                      17.9%   8.4%   3.1%   6.4%  12.3%
# Textiles                                 2.8%   2.9%   6.3%  11.4%  13.9%
# Wood                                     Neg.   Neg.   Neg.   1.1%  10.1%
# Other **                                 Neg.  39.0%  19.8%  21.3%  24.5%
# ...

# %%
recycled_percent.to_csv("percent_recycled_table.csv")

# %%
composted
# Out:
#                      Food - composted Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0                               Food^       Neg.       Neg.       Neg.
# 1          Yard Trimmings - composted        NaN        NaN        NaN
# 2                      Yard Trimmings       Neg.       Neg.       Neg.
# 3  Misc. Inorganic Wastes - composted        NaN        NaN        NaN
# 4      Miscellaneous Inorganic Wastes       Neg.       Neg.       Neg.
# 5                   Total - composted       Neg.       Neg.       Neg.
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0       Neg.        680        690        970      2,100      2,570      2,590
# 1        NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 2      4,200     15,770     19,860     19,200     21,290     24,420     22,300
# 3        NaN        NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
# food - composted, yard trimmings -composted, and misc - composted were just labels in table so droping them
composted.drop([1,3], inplace=True)

# renaming columns and setting index to row labels
composted.columns = column_names
composted.set_index('Material', inplace=True)
composted
# Out:
#                                 1960  1970  1980   1990    2000    2005  \
# Material
# Food^                           Neg.  Neg.  Neg.   Neg.     680     690
# Yard Trimmings                  Neg.  Neg.  Neg.  4,200  15,770  19,860
# Miscellaneous Inorganic Wastes  Neg.  Neg.  Neg.   Neg.    Neg.    Neg.
# Total - composted               Neg.  Neg.  Neg.  4,200  16,450  20,550
#
#                                   2010    2015    2017    2018
# Material
# Food^                              970   2,100   2,570   2,590
# Yard Trimmings                  19,200  21,290  24,420  22,300
# Miscellaneous Inorganic Wastes    Neg.    Neg.    Neg.    Neg.
# Total - composted               20,170  23,390  26,990  24,890

# %%
composted.to_csv("absolute_composted_table.csv")

# %%
composted_percent
# Out:
#                      Food - Composted Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0                               Food^       Neg.       Neg.       Neg.
# 1          Yard Trimmings - Composted        NaN        NaN        NaN
# 2                      Yard Trimmings       Neg.       Neg.       Neg.
# 3  Misc. Inorganic Wastes – composted        NaN        NaN        NaN
# 4      Miscellaneous Inorganic Wastes       Neg.       Neg.       Neg.
# 5                   Total – composted       Neg.       Neg.       Neg.
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 0       Neg.       2.2%       2.1%       2.7%       5.3%       6.3%       4.1%
# 1        NaN        NaN        NaN        NaN        NaN        NaN        NaN
# 2      12.0%      51.7%      61.9%      57.5%      61.3%      69.4%      63.0%
# 3        NaN        NaN        NaN        NaN        NaN        NaN        NaN
# ...

# %%
# food - composted, yard trimmings -composted, and misc - composted were just labels in table so droping them
composted_percent.drop([1,3], inplace=True)

composted_percent.columns=column_names
composted_percent.set_index('Material', inplace=True)
composted_percent
# Out:
#                                 1960  1970  1980   1990   2000   2005   2010  \
# Material
# Food^                           Neg.  Neg.  Neg.   Neg.   2.2%   2.1%   2.7%
# Yard Trimmings                  Neg.  Neg.  Neg.  12.0%  51.7%  61.9%  57.5%
# Miscellaneous Inorganic Wastes  Neg.  Neg.  Neg.   Neg.   Neg.   Neg.   Neg.
# Total – composted               Neg.  Neg.  Neg.   6.8%  25.4%  29.9%  27.6%
#
#                                  2015   2017   2018
# Material
# Food^                            5.3%   6.3%   4.1%
# Yard Trimmings                  61.3%  69.4%  63.0%
# Miscellaneous Inorganic Wastes   Neg.   Neg.   Neg.
# Total – composted               29.8%  33.8%  24.3%

# %%
combusted_percent.to_csv("percent_composted_table.csv")

# %%
other
# Out:
#                                             Material  Amount
# 0                                 Food - animal feed   1,820
# 1  Food - bio-based materials/biochemical processing   1,840
# 2             Food – codigestion/anaerobic digestion   5,260
# 3                                    Food - donation   4,790
# 4                            Food - land application     260
# 5                  Food – sewer/wastewater treatment   3,740
# 6                 Total Food – other food management  17,710

# %%
# making clear the data is from 2018 and reseting index before saving
other.columns=['Material', '2018']
other.set_index('Material', inplace=True)
other
# Out:
#                                                      2018
# Material
# Food - animal feed                                  1,820
# Food - bio-based materials/biochemical processing   1,840
# Food – codigestion/anaerobic digestion              5,260
# Food - donation                                     4,790
# Food - land application                               260
# Food – sewer/wastewater treatment                   3,740
# Total Food – other food management                 17,710

# %%
other.to_csv("other_food_managment_2018_absolute.csv")

# %%
other_percent
# Out:
#                                             Material Percent
# 0                                 Food - animal feed    2.9%
# 1  Food - bio-based materials/biochemical processing    2.9%
# 2             Food – codigestion/anaerobic digestion    8.3%
# 3                                    Food - donation    7.6%
# 4                            Food - land application    0.4%
# 5                  Food – sewer/wastewater treatment    5.9%
# 6                 Total Food – other food management   28.1%

# %%
other_percent.columns=['Material', '2018']
other_percent.set_index('Material', inplace=True)
other_percent
# Out:
#                                                     2018
# Material
# Food - animal feed                                  2.9%
# Food - bio-based materials/biochemical processing   2.9%
# Food – codigestion/anaerobic digestion              8.3%
# Food - donation                                     7.6%
# Food - land application                             0.4%
# Food – sewer/wastewater treatment                   5.9%
# Total Food – other food management                 28.1%

# %%
other_percent.to_csv("other_food_managment_2018_percent.csv")

# %%
combusted
# Out:
#                         Unnamed: 0  1960   1970   1980    1990    2000  \
# 0             Paper and Paperboard   NaN  150.0    860   8,930   9,730
# 1                            Glass   NaN   60.0    300   1,810   1,790
# 2                           Metals   NaN    NaN    NaN     NaN     NaN
# 3                          Ferrous   NaN   60.0    250   1,690   1,610
# 4                         Aluminum   NaN    0.0     30     300     390
# 5                 Other Nonferrous   NaN    0.0     20      60      50
# 6                     Total Metals   NaN   60.0    300   2,050   2,050
# 7                         Plastics   NaN    0.0    140   2,980   4,120
# 8               Rubber and Leather   NaN   10.0     70     830   1,970
# 9                         Textiles   NaN   10.0     50     880   1,880
# 10                            Wood   NaN   10.0    150   2,080   2,290
# 11                        Other **   NaN    0.0     30     410     540
# ...

# %%
# removing metal and other wastes rows that were just labels in table and relabing data for clarity
combusted.iloc[3,0] = combusted.iloc[2,0] +" - "+combusted.iloc[3,0]
combusted.iloc[4,0] = combusted.iloc[2,0] +" - "+combusted.iloc[4,0]
combusted.iloc[5,0] = combusted.iloc[2,0] +" - "+combusted.iloc[5,0]
combusted.drop([2,13], inplace=True)
combusted.columns = column_names

# renaming columns and setting index to row labels
combusted.set_index('Material', inplace=True)
combusted
# Out:
#                                 1960   1970   1980    1990    2000    2005  \
# Material
# Paper and Paperboard             NaN  150.0    860   8,930   9,730   7,800
# Glass                            NaN   60.0    300   1,810   1,790   1,660
# Metals - Ferrous                 NaN   60.0    250   1,690   1,610   1,640
# Metals - Aluminum                NaN    0.0     30     300     390     410
# Metals - Other Nonferrous        NaN    0.0     20      60      50      50
# Total Metals                     NaN   60.0    300   2,050   2,050   2,100
# Plastics                         NaN    0.0    140   2,980   4,120   4,330
# Rubber and Leather               NaN   10.0     70     830   1,970   2,110
# Textiles                         NaN   10.0     50     880   1,880   2,110
# Wood                             NaN   10.0    150   2,080   2,290   2,270
# Other **                         NaN    0.0     30     410     540     510
# ...

# %%
combusted.to_csv("absolute_combusted_table.csv")

# %%
combusted_percent
# Out:
#                                      Unnamed: 0  1960    1970    1980    1990  \
# 0                          Paper and Paperboard   NaN   33.3%   31.2%   30.0%
# 1                                         Glass   NaN   13.3%   10.9%    6.1%
# 2                                        Metals   NaN     NaN     NaN     NaN
# 3                                       Ferrous   NaN   13.3%    9.0%    5.7%
# 4                                      Aluminum   NaN    0.0%    1.1%    1.0%
# 5                              Other Nonferrous   NaN    0.0%    0.7%    0.2%
# 6                                  Total Metals   NaN   13.3%   10.8%    6.9%
# 7                                      Plastics   NaN    Neg.    5.1%   10.0%
# 8                            Rubber and Leather   NaN    2.2%    2.5%    2.8%
# 9                                      Textiles   NaN    2.2%    1.8%    2.9%
# 10                                         Wood   NaN    2.2%    5.4%    7.0%
# ...

# %%
# removing metal and other wastes rows that were just labels in table and relabing data for clarity
combusted_percent.iloc[3,0] = combusted_percent.iloc[2,0] +" - "+combusted_percent.iloc[3,0]
combusted_percent.iloc[4,0] = combusted_percent.iloc[2,0] +" - "+combusted_percent.iloc[4,0]
combusted_percent.iloc[5,0] = combusted_percent.iloc[2,0] +" - "+combusted_percent.iloc[5,0]
combusted_percent.drop([2,13], inplace=True)
combusted_percent.columns = column_names

# renaming columns and setting index to row labels
combusted_percent.set_index('Material', inplace=True)
combusted_percent
# Out:
#                                              1960    1970    1980    1990  \
# Material
# Paper and Paperboard                          NaN   33.3%   31.2%   30.0%
# Glass                                         NaN   13.3%   10.9%    6.1%
# Metals - Ferrous                              NaN   13.3%    9.0%    5.7%
# Metals - Aluminum                             NaN    0.0%    1.1%    1.0%
# Metals - Other Nonferrous                     NaN    0.0%    0.7%    0.2%
# Total Metals                                  NaN   13.3%   10.8%    6.9%
# Plastics                                      NaN    Neg.    5.1%   10.0%
# Rubber and Leather                            NaN    2.2%    2.5%    2.8%
# Textiles                                      NaN    2.2%    1.8%    2.9%
# Wood                                          NaN    2.2%    5.4%    7.0%
# Other **                                      NaN    Neg.    1.1%    1.4%
# ...

# %%
combusted_percent.to_csv("percent_combusted_table.csv")

# %%
landfilled
# Out:
#                      Unnamed: 0    1960    1970    1980    1990     2000  \
# 0          Paper and Paperboard  24,910  37,390  42,560  43,570   40,450
# 1                         Glass   6,620  12,520  14,080   8,660    8,100
# 2                        Metals     NaN     NaN     NaN     NaN      NaN
# 3                       Ferrous  10,250  12,150  12,000   8,720    7,860
# 4                      Aluminum     340     790   1,390   1,500    1,940
# 5              Other Nonferrous     180     350     600     310      490
# 6                  Total Metals  10,770  13,290  13,990  10,530   10,290
# 7                      Plastics     390   2,900   6,670  13,780   19,950
# 8            Rubber and Leather   1,510   2,710   4,000   4,590    3,880
# 9                      Textiles   1,710   1,970   2,320   4,270    6,280
# 10                         Wood   3,030   3,710   6,860  10,000    9,910
# 11                     Other **      70     470   1,990   2,100    2,480
# ...

# %%
# removing metal and other wastes rows that were just labels in table and relabing data for clarity
landfilled.iloc[3,0] = landfilled.iloc[2,0] +" - "+landfilled.iloc[3,0]
landfilled.iloc[4,0] = landfilled.iloc[2,0] +" - "+landfilled.iloc[4,0]
landfilled.iloc[5,0] = landfilled.iloc[2,0] +" - "+landfilled.iloc[5,0]
landfilled.drop([2,13], inplace=True)
landfilled.columns = column_names

# renaming columns and setting index to row labels
landfilled.set_index('Material', inplace=True)
landfilled
# Out:
#                                1960    1970    1980    1990     2000     2005  \
# Material
# Paper and Paperboard         24,910  37,390  42,560  43,570   40,450   35,080
# Glass                         6,620  12,520  14,080   8,660    8,100    8,290
# Metals - Ferrous             10,250  12,150  12,000   8,720    7,860    8,550
# Metals - Aluminum               340     790   1,390   1,500    1,940    2,230
# Metals - Other Nonferrous       180     350     600     310      490      530
# Total Metals                 10,770  13,290  13,990  10,530   10,290   11,310
# Plastics                        390   2,900   6,670  13,780   19,950   23,270
# Rubber and Leather            1,510   2,710   4,000   4,590    3,880    4,130
# Textiles                      1,710   1,970   2,320   4,270    6,280    7,570
# Wood                          3,030   3,710   6,860  10,000    9,910   10,690
# Other **                         70     470   1,990   2,100    2,480    2,570
# ...

# %%
landfilled.to_csv("absolute_landfilled_table.csv")

# %%
landfilled_percent
# Out:
#                      Unnamed: 0   1960   1970   1980   1990   2000   2005  \
# 0          Paper and Paperboard  30.2%  33.2%  31.7%  30.0%  28.8%  24.7%
# 1                         Glass   8.0%  11.1%  10.5%   6.0%   5.8%   5.8%
# 2                        Metals    NaN    NaN    NaN    NaN    NaN    NaN
# 3                       Ferrous  12.4%  10.8%   8.9%   6.0%   5.6%   6.0%
# 4                      Aluminum   0.4%   0.7%   1.0%   1.0%   1.4%   1.6%
# 5              Other Nonferrous   0.2%   0.3%   0.4%   0.2%   0.3%   0.3%
# 6                  Total Metals  13.0%  11.8%  10.3%   7.2%   7.3%   7.9%
# 7                      Plastics   0.5%   2.6%   5.0%   9.5%  14.2%  16.4%
# 8            Rubber and Leather   1.8%   2.4%   3.0%   3.2%   2.8%   2.9%
# 9                      Textiles   2.1%   1.7%   1.7%   2.9%   4.5%   5.3%
# 10                         Wood   3.7%   3.3%   5.1%   6.9%   7.1%   7.5%
# 11                     Other **   0.1%   0.4%   1.5%   1.4%   1.8%   1.8%
# ...

# %%
# removing metal and other wastes rows that were just labels in table and relabing data for clarity
landfilled_percent.iloc[3,0] = landfilled_percent.iloc[2,0] +" - "+landfilled_percent.iloc[3,0]
landfilled_percent.iloc[4,0] = landfilled_percent.iloc[2,0] +" - "+landfilled_percent.iloc[4,0]
landfilled_percent.iloc[5,0] = landfilled_percent.iloc[2,0] +" - "+landfilled_percent.iloc[5,0]
landfilled_percent.drop([2,13], inplace=True)
landfilled_percent.columns = column_names

# renaming columns and setting index to row labels
landfilled_percent.set_index('Material', inplace=True)
landfilled_percent
# Out:
#                               1960   1970   1980   1990   2000   2005   2010  \
# Material
# Paper and Paperboard         30.2%  33.2%  31.7%  30.0%  28.8%  24.7%  16.1%
# Glass                         8.0%  11.1%  10.5%   6.0%   5.8%   5.8%   5.1%
# Metals - Ferrous             12.4%  10.8%   8.9%   6.0%   5.6%   6.0%   6.8%
# Metals - Aluminum             0.4%   0.7%   1.0%   1.0%   1.4%   1.6%   1.8%
# Metals - Other Nonferrous     0.2%   0.3%   0.4%   0.2%   0.3%   0.3%   0.4%
# Total Metals                 13.0%  11.8%  10.3%   7.2%   7.3%   7.9%   9.0%
# Plastics                      0.5%   2.6%   5.0%   9.5%  14.2%  16.4%  17.9%
# Rubber and Leather            1.8%   2.4%   3.0%   3.2%   2.8%   2.9%   3.2%
# Textiles                      2.1%   1.7%   1.7%   2.9%   4.5%   5.3%   6.5%
# Wood                          3.7%   3.3%   5.1%   6.9%   7.1%   7.5%   8.2%
# Other **                      0.1%   0.4%   1.5%   1.4%   1.8%   1.8%   2.1%
# ...

# %%
landfilled_percent.to_csv("percent_landfilled_table.csv")

# %% [markdown]
# ## Merging Data

# %%
generated_absolute = generated_absolute.T
# Out:
# Material Paper and Paperboard   Glass Metals - Ferrous Metals - Aluminum  \
# 1960                   29,990   6,720           10,300               340
# 1970                   44,310  12,740           12,360               800
# 1980                   55,160  15,130           12,620             1,730
# 1990                   72,730  13,100           12,640             2,810
# 2000                   87,740  12,770           14,150             3,190
# 2005                   84,840  12,540           15,210             3,330
# 2010                   71,310  11,520           16,920             3,510
# 2015                   68,050  11,470           18,190             3,670
# 2017                   67,010  12,300           18,890             3,820
# 2018                   67,390  12,250           19,200             3,890
#
# Material Metals - Other Nonferrous Metals - Total Metals Plastics  \
# 1960                           180                10,820      390
# ...

# %%
generated_absolute = generated_absolute.add_prefix('Generated ') 
generated_absolute
# Out:
# Material Generated Paper and Paperboard Generated Glass  \
# 1960                             29,990           6,720
# 1970                             44,310          12,740
# 1980                             55,160          15,130
# 1990                             72,730          13,100
# 2000                             87,740          12,770
# 2005                             84,840          12,540
# 2010                             71,310          11,520
# 2015                             68,050          11,470
# 2017                             67,010          12,300
# 2018                             67,390          12,250
#
# Material Generated Metals - Ferrous Generated Metals - Aluminum  \
# 1960                         10,300                         340
# 1970                         12,360                         800
# 1980                         12,620                       1,730
# 1990                         12,640                       2,810
# ...

# %%
recycled = recycled.T
recycled = recycled.add_prefix('Recycled ')
recycled
# Out:
# Material Recycled Paper and Paperboard Recycled Glass  \
# 1960                             5,080            100
# 1970                             6,770            160
# 1980                            11,740            750
# 1990                            20,230          2,630
# 2000                            37,560          2,880
# 2005                            41,960          2,590
# 2010                            44,570          3,130
# 2015                            45,320          3,190
# 2017                            44,170          3,070
# 2018                            45,970          3,060
#
# Material Recycled Metals - Ferrous Recycled Metals - Aluminum  \
# 1960                            50                       Neg.
# 1970                           150                         10
# 1980                           370                        310
# 1990                         2,230                      1,010
# ...

# %%
composted = composted.T
composted = composted.add_prefix('Composted ')
composted
# Out:
# Material Composted Food^ Composted Yard Trimmings  \
# 1960                Neg.                     Neg.
# 1970                Neg.                     Neg.
# 1980                Neg.                     Neg.
# 1990                Neg.                    4,200
# 2000                 680                   15,770
# 2005                 690                   19,860
# 2010                 970                   19,200
# 2015               2,100                   21,290
# 2017               2,570                   24,420
# 2018               2,590                   22,300
#
# Material Composted Miscellaneous Inorganic Wastes Composted Total - composted
# 1960                                         Neg.                        Neg.
# 1970                                         Neg.                        Neg.
# 1980                                         Neg.                        Neg.
# 1990                                         Neg.                       4,200
# ...

# %%
combusted = combusted.T
combusted = combusted.add_prefix('Combusted ')
combusted
# Out:
# Material Combusted Paper and Paperboard Combusted Glass  \
# 1960                                NaN             NaN
# 1970                                150              60
# 1980                                860             300
# 1990                              8,930           1,810
# 2000                              9,730           1,790
# 2005                              7,800           1,660
# 2010                              4,740           1,360
# 2015                              4,450           1,440
# 2017                              4,490           1,650
# 2018                              4,200           1,640
#
# Material Combusted Metals - Ferrous Combusted Metals - Aluminum  \
# 1960                            NaN                         NaN
# 1970                             60                           0
# 1980                            250                          30
# 1990                          1,690                         300
# ...

# %%
landfilled = landfilled.T
landfilled = landfilled.add_prefix("Landfilled ")
landfilled
# Out:
# Material Landfilled Paper and Paperboard Landfilled Glass  \
# 1960                              24,910            6,620
# 1970                              37,390           12,520
# 1980                              42,560           14,080
# 1990                              43,570            8,660
# 2000                              40,450            8,100
# 2005                              35,080            8,290
# 2010                              22,000            7,030
# 2015                              18,280            6,840
# 2017                              18,350            7,580
# 2018                              17,220            7,550
#
# Material Landfilled Metals - Ferrous Landfilled Metals - Aluminum  \
# 1960                          10,250                          340
# 1970                          12,150                          790
# 1980                          12,000                        1,390
# ...

# %%
recycled.reset_index(inplace=True)
recycled.drop(columns=['index'], inplace=True)
recycled.columns.name = None
recycled
# Out:
#   Recycled Paper and Paperboard Recycled Glass Recycled Metals - Ferrous  \
# 0                         5,080            100                        50
# 1                         6,770            160                       150
# 2                        11,740            750                       370
# 3                        20,230          2,630                     2,230
# 4                        37,560          2,880                     4,680
# 5                        41,960          2,590                     5,020
# 6                        44,570          3,130                     5,800
# 7                        45,320          3,190                     6,070
# 8                        44,170          3,070                     6,170
# 9                        45,970          3,060                     6,360
#
#   Recycled Metals - Aluminum Recycled Metals - Other Nonferrous  \
# 0                       Neg.                               Neg.
# ...

# %%
composted.reset_index(inplace=True)
composted.drop(columns=['index'], inplace=True)
composted.columns.name = None
composted
# Out:
#   Composted Food^ Composted Yard Trimmings  \
# 0            Neg.                     Neg.
# 1            Neg.                     Neg.
# 2            Neg.                     Neg.
# 3            Neg.                    4,200
# 4             680                   15,770
# 5             690                   19,860
# 6             970                   19,200
# 7           2,100                   21,290
# 8           2,570                   24,420
# 9           2,590                   22,300
#
#   Composted Miscellaneous Inorganic Wastes Composted Total - composted
# 0                                     Neg.                        Neg.
# 1                                     Neg.                        Neg.
# 2                                     Neg.                        Neg.
# 3                                     Neg.                       4,200
# 4                                     Neg.                      16,450
# ...

# %%
combusted.reset_index(inplace=True)
combusted.drop(columns=['index'], inplace=True)
combusted.columns.name = None
combusted
# Out:
#   Combusted Paper and Paperboard Combusted Glass Combusted Metals - Ferrous  \
# 0                            NaN             NaN                        NaN
# 1                            150              60                         60
# 2                            860             300                        250
# 3                          8,930           1,810                      1,690
# 4                          9,730           1,790                      1,610
# 5                          7,800           1,660                      1,640
# 6                          4,740           1,360                      1,810
# 7                          4,450           1,440                      2,150
# 8                          4,490           1,650                      2,290
# 9                          4,200           1,640                      2,310
#
#   Combusted Metals - Aluminum Combusted Metals - Other Nonferrous  \
# ...

# %%
landfilled.reset_index(inplace=True)
landfilled.drop(columns=['index'], inplace=True)
landfilled.columns.name = None
landfilled
# Out:
#   Landfilled Paper and Paperboard Landfilled Glass  \
# 0                          24,910            6,620
# 1                          37,390           12,520
# 2                          42,560           14,080
# 3                          43,570            8,660
# 4                          40,450            8,100
# 5                          35,080            8,290
# 6                          22,000            7,030
# 7                          18,280            6,840
# 8                          18,350            7,580
# 9                          17,220            7,550
#
#   Landfilled Metals - Ferrous Landfilled Metals - Aluminum  \
# 0                      10,250                          340
# 1                      12,150                          790
# 2                      12,000                        1,390
# 3                       8,720                        1,500
# 4                       7,860                        1,940
# ...

# %%
generated_absolute.columns.name = None
generated_absolute.reset_index(inplace=True)
generated_absolute
# Out:
#   index Generated Paper and Paperboard Generated Glass  \
# 0  1960                         29,990           6,720
# 1  1970                         44,310          12,740
# 2  1980                         55,160          15,130
# 3  1990                         72,730          13,100
# 4  2000                         87,740          12,770
# 5  2005                         84,840          12,540
# 6  2010                         71,310          11,520
# 7  2015                         68,050          11,470
# 8  2017                         67,010          12,300
# 9  2018                         67,390          12,250
#
#   Generated Metals - Ferrous Generated Metals - Aluminum  \
# 0                     10,300                         340
# 1                     12,360                         800
# 2                     12,620                       1,730
# 3                     12,640                       2,810
# 4                     14,150                       3,190
# ...

# %%
merged = pd.concat([generated_absolute, recycled, composted, combusted, landfilled], axis=1)

# %%
merged
# Out:
#   index Generated Paper and Paperboard Generated Glass  \
# 0  1960                         29,990           6,720
# 1  1970                         44,310          12,740
# 2  1980                         55,160          15,130
# 3  1990                         72,730          13,100
# 4  2000                         87,740          12,770
# 5  2005                         84,840          12,540
# 6  2010                         71,310          11,520
# 7  2015                         68,050          11,470
# 8  2017                         67,010          12,300
# 9  2018                         67,390          12,250
#
#   Generated Metals - Ferrous Generated Metals - Aluminum  \
# 0                     10,300                         340
# 1                     12,360                         800
# 2                     12,620                       1,730
# 3                     12,640                       2,810
# 4                     14,150                       3,190
# ...

# %%
merged.rename(columns={'index': 'Year'}, inplace=True)
merged
# Out:
#    Year Generated Paper and Paperboard Generated Glass  \
# 0  1960                         29,990           6,720
# 1  1970                         44,310          12,740
# 2  1980                         55,160          15,130
# 3  1990                         72,730          13,100
# 4  2000                         87,740          12,770
# 5  2005                         84,840          12,540
# 6  2010                         71,310          11,520
# 7  2015                         68,050          11,470
# 8  2017                         67,010          12,300
# 9  2018                         67,390          12,250
#
#   Generated Metals - Ferrous Generated Metals - Aluminum  \
# 0                     10,300                         340
# 1                     12,360                         800
# 2                     12,620                       1,730
# 3                     12,640                       2,810
# 4                     14,150                       3,190
# ...

# %%
merged.replace("Neg.", 0, inplace = True)
merged.fillna(value = 0, inplace= True)

# %%
merged.to_csv("absolute_table.csv")

# %%
merged["Combusted Food"]
# Out:
# 0      NaN
# 1       50
# 2      260
# 3    4,060
# 4    5,820
# 5    5,870
# 6    6,150
# 7    7,380
# 8    7,470
# 9    7,550
# Name: Combusted Food, dtype: object

# %%
len(merged.columns)
# Out:
# 68

# %%
composted
# Out:
#   Composted Food^ Composted Yard Trimmings  \
# 0            Neg.                     Neg.
# 1            Neg.                     Neg.
# 2            Neg.                     Neg.
# 3            Neg.                    4,200
# 4             680                   15,770
# 5             690                   19,860
# 6             970                   19,200
# 7           2,100                   21,290
# 8           2,570                   24,420
# 9           2,590                   22,300
#
#   Composted Miscellaneous Inorganic Wastes Composted Total - composted
# 0                                     Neg.                        Neg.
# 1                                     Neg.                        Neg.
# 2                                     Neg.                        Neg.
# 3                                     Neg.                       4,200
# 4                                     Neg.                      16,450
# ...
